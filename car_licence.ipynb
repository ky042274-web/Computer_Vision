# %%
# !pip install ultralytics easyocr opencv-python matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --------------------- ------------------ 1.6/2.9 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 10.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/40.1 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/40.1 MB 11.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/40.1 MB 11.4 MB/s eta 0:00:04
#    ------- -------------------------------- 7.1/40.1 MB 11.2 MB/s eta 0:00:03
#    --------- ------------------------------ 9.2/40.1 MB 11.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.3/40.1 MB 10.7 MB/s eta 0:00:03
#    ------------- -------------------------- 13.6/40.1 MB 10.7 MB/s eta 0:00:03
#    --------------- ------------------------ 16.0/40.1 MB 10.8 MB/s eta 0:00:03
#    ------------------ --------------------- 18.6/40.1 MB 11.0 MB/s eta 0:00:02
# ...

# %%
# !pip install easyocr
# !pip install easyocr opencv-python torch torchvision
# !pip install easyocr opencv-python torch torchvision
# Out:
# ...
#   Using cached easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached opencv_python_headless-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached scikit_image-0.26.0-cp312-cp312-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached ninja-1.13.0-py3-none-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Using cached easyocr-1.7.2-py3-none-any.whl (2.9 MB)
# Using cached ninja-1.13.0-py3-none-win_amd64.whl (309 kB)
# Using cached opencv_python_headless-4.13.0.92-cp37-abi3-win_amd64.whl (40.1 MB)
# Using cached scikit_image-0.26.0-cp312-cp312-win_amd64.whl (11.9 MB)
# Using cached imageio-2.37.3-py3-none-any.whl (317 kB)
# Using cached lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# ...
#
#    ---------------------------------------- 0/6 [opencv-python-headless]
# ...

# %%
import sys
# !{sys.executable} -m pip install easyocr
# Out:
# ...
#   Using cached easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached opencv_python_headless-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached scikit_image-0.26.0-cp312-cp312-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached ninja-1.13.0-py3-none-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Using cached easyocr-1.7.2-py3-none-any.whl (2.9 MB)
# Using cached ninja-1.13.0-py3-none-win_amd64.whl (309 kB)
# Using cached opencv_python_headless-4.13.0.92-cp37-abi3-win_amd64.whl (40.1 MB)
# Using cached scikit_image-0.26.0-cp312-cp312-win_amd64.whl (11.9 MB)
# Using cached imageio-2.37.3-py3-none-any.whl (317 kB)
# Using cached lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# ...
#
#    ---------------------------------------- 0/6 [opencv-python-headless]
# ...

# %%
import os
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
# Dataset folder path
dataset_path = "car_licence"

print("Dataset Loaded Successfully")
print("Files:", os.listdir(dataset_path)[:5])
# Out:
# Dataset Loaded Successfully
# Files: ['annotations', 'images']

# %%
# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# %%
import cv2
import matplotlib.pyplot as plt

image_path = "car_licence/images/Cars43.png"

image = cv2.imread(image_path)

if image is None:
    print("Still image not found")
else:
    print("Image Loaded Successfully")

    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(10,6))
    plt.imshow(image_rgb)
    plt.title("Original Image")
    plt.axis("off")
    plt.show()
# Out:
# Image Loaded Successfully

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load YOLO model
model = YOLO("yolov8n.pt")

# Image path
image_path = "car_licence/images/Cars1.png"

# Read image
image = cv2.imread(image_path)

# Run detection
results = model(image)

# Copy image
img_copy = image.copy()

# Variable for plate crop
plate_crop = None

# Draw bounding boxes
for result in results:

    boxes = result.boxes.xyxy.cpu().numpy()

    for box in boxes:

        x1, y1, x2, y2 = map(int, box[:4])

        # Draw rectangle
        cv2.rectangle(img_copy, (x1, y1), (x2, y2), (0,255,0), 2)

        # Crop detected region
        plate_crop = image[y1:y2, x1:x2]

# Convert image for display
img_rgb = cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB)

# Show output
plt.figure(figsize=(12,6))
plt.imshow(img_rgb)
plt.title("Detected Number Plate")
plt.axis("off")
plt.show()
# Out:
# 0: 416x640 2 cars, 1 truck, 62.7ms
# Speed: 2.5ms preprocess, 62.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)

# %%
import cv2
import matplotlib.pyplot as plt

image_path = "car_licence/images/Cars43.png"

image = cv2.imread(image_path)

if image is None:
    print("Still image not found")
else:
    print("Image Loaded Successfully")

    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(10,6))
    plt.imshow(image_rgb)
    plt.title("Original Image")
    plt.axis("off")
    plt.show()
# Out:
# Still image not found
